# %% [markdown]
# # Fase 9 — Actualización dinámica por jornada
#
# Este notebook ejecuta el mismo flujo que `scripts/update_season.py`. Antes de usarlo, completa las plantillas de `data/incoming/`.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
sys.path.insert(0, str(PROJECT_ROOT / 'src'))

from laliga_predictor.dynamic import run_phase9

# %%
summary = run_phase9()
summary

# %%
import pandas as pd

next_matchday = pd.read_csv(PROJECT_ROOT / 'reports' / 'dynamic_next_matchday_predictions.csv')
next_matchday[['matchday', 'home_team', 'away_team', 'model', 'probability_home', 'probability_draw', 'probability_away', 'predicted_score']]

# %%
season = pd.read_csv(PROJECT_ROOT / 'reports' / 'dynamic_season_simulation_summary.csv')
season[['team', 'expected_points', 'champion_probability', 'top4_probability', 'europe_top7_probability', 'relegation_probability']].head(20)
