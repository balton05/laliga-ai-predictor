# %% [markdown]
# # Fase 6 — Random Forest y boosting
#
# Este notebook ejecuta la búsqueda temporal de modelos avanzados, abre 2025/26 una sola vez y genera las predicciones preliminares 2026/27.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT / 'src'))

from laliga_predictor.advanced_modeling import run_phase6
summary = run_phase6()
summary

# %%
import pandas as pd

metrics = pd.read_csv(PROJECT_ROOT / 'reports' / 'phase6_model_comparison.csv')
metrics.sort_values(['split', 'log_loss'])

# %%
bootstrap = pd.read_csv(PROJECT_ROOT / 'reports' / 'advanced_model_bootstrap_comparison.csv')
bootstrap

# %%
importance = pd.read_csv(PROJECT_ROOT / 'reports' / 'advanced_model_feature_importance.csv')
importance.query('rank <= 10').sort_values(['model', 'rank'])

# %%
fixtures = pd.read_csv(PROJECT_ROOT / 'data' / 'processed' / 'fixtures_2026_27_advanced_predictions.csv')
fixtures.head(20)
