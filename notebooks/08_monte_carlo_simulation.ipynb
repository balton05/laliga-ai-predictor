# %% [markdown]
# # Fase 8 — Simulación Monte Carlo
#
# Ejecuta 50,000 temporadas de LaLiga 2026/27 con el ensemble deportivo y marcadores Poisson condicionados.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
sys.path.insert(0, str(PROJECT_ROOT / 'src'))

from laliga_predictor.simulation import run_phase8
summary = run_phase8()
summary

# %%
import pandas as pd

table = pd.read_csv(PROJECT_ROOT / 'reports' / 'season_simulation_summary.csv')
table[['team', 'expected_points', 'champion_probability', 'top4_probability', 'europe_top7_probability', 'relegation_probability']]

# %%
pd.read_csv(PROJECT_ROOT / 'reports' / 'simulation_convergence.csv')
