# %% [markdown]
# # Fase 7 — Calibración y ensembles
#
# Este notebook ejecuta la calibración por temperatura y combina mercado, Random Forest, regresión logística y Poisson. Los parámetros se seleccionan únicamente con 2023/24–2024/25; 2025/26 se conserva como prueba final.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent
sys.path.insert(0, str(PROJECT_ROOT / "src"))

from laliga_predictor.ensembling import run_phase7

# %%
summary = run_phase7()
summary

# %%
import pandas as pd

metrics = pd.read_csv(PROJECT_ROOT / "reports" / "ensemble_metrics.csv")
metrics.sort_values(["split", "log_loss"])

# %%
selection = pd.read_json(PROJECT_ROOT / "reports" / "ensemble_selection.json")
selection

# %%
fixtures = pd.read_csv(
    PROJECT_ROOT / "data" / "processed" / "fixtures_2026_27_ensemble_predictions.csv"
)
fixtures.head(10)

# %% [markdown]
# ## Interpretación
#
# - `ensemble_sports` es la salida utilizable antes de que existan cuotas 2026/27.
# - `ensemble_market` debe emplearse únicamente con probabilidades implícitas actuales y normalizadas.
# - Una mejora numérica no se considera concluyente si el intervalo bootstrap de la diferencia incluye cero.
