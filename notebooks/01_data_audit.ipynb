# %% [markdown]
# # 01 · Auditoría de datos
#
# Ejecuta la tubería reproducible de la Fase 1 y revisa sus principales salidas.

# %%
from pathlib import Path
import sys
import pandas as pd

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT / 'src'))

from laliga_predictor.pipeline import run_phase1

summary = run_phase1()
summary

# %%
audit = pd.read_csv(PROJECT_ROOT / 'reports' / 'data_audit.csv')
audit

# %%
promotions = pd.read_csv(PROJECT_ROOT / 'data' / 'processed' / 'historical_promotions.csv')
promotions.tail(15)

# %%
fixtures = pd.read_csv(PROJECT_ROOT / 'data' / 'processed' / 'fixtures_2026_27.csv')
fixtures.head(10)
