# %% [markdown]
# # Fase 4 — Baselines y regresión logística multinomial
#
# Este notebook ejecuta la comparación temporal de frecuencia histórica, mercado, Elo y dos regresiones logísticas. La temporada 2025/26 se abre una sola vez después de seleccionar la regularización con validación walk-forward.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT / 'src'))

from laliga_predictor.modeling import run_phase4

summary = run_phase4()
summary

# %%
import pandas as pd
from IPython.display import display, Image

metrics = pd.read_csv(PROJECT_ROOT / 'reports' / 'model_metrics.csv')
display(metrics.round(4))

# %%
candidates = pd.read_csv(PROJECT_ROOT / 'reports' / 'model_candidate_validation.csv')
display(candidates[candidates['fold'].eq('COMBINED')].sort_values(['model', 'log_loss']).round(4))

# %%
display(Image(filename=PROJECT_ROOT / 'reports' / 'figures' / '08_comparacion_validacion.png'))
display(Image(filename=PROJECT_ROOT / 'reports' / 'figures' / '09_comparacion_prueba.png'))
display(Image(filename=PROJECT_ROOT / 'reports' / 'figures' / '10_calibracion_prueba.png'))

# %%
coefficients = pd.read_csv(PROJECT_ROOT / 'reports' / 'logistic_coefficients.csv')
display(coefficients.groupby('model').head(15).round(4))
display(Image(filename=PROJECT_ROOT / 'reports' / 'figures' / '12_coeficientes_logistic_market.png'))

# %% [markdown]
# ## Resultado
#
# El mercado es el baseline campeón por Log Loss. La regresión logística deportiva queda como referencia sin cuotas. La siguiente fase comparará ambos contra Poisson y Dixon-Coles.
